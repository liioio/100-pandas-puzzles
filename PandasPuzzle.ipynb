# %% [markdown]
# <a href="https://colab.research.google.com/github/liioio/100-pandas-puzzles/blob/master/PandasPuzzle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 1
# Out:
# 2

# %%
! git clone https://github.com/liioio/100-pandas-puzzles.git
